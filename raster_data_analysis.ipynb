# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinssvps/Amazon-forest-fires-over-the-years-final/blob/master/raster_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import geopandas as gpd

# %%
# !pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import rasterio

# %%
rasterio.__version__
# Out:
# '1.2.6'

# %%
in_img = r'/content/data/nepal_lc_2020.tif'
ds = rasterio.open(in_img)
ds
# Out:
# <open DatasetReader name='/content/data/nepal_lc_2020.tif' mode='r'>

# %%
data = ds.read()
data
# Out:
# array([[[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255]]], dtype=uint8)

# %%
ds.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': 255.0,
#  'width': 2932,
#  'height': 1485,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(0.0027777777777780012, 0.0, 80.05847091000004,
#         0.0, -0.0027777777777780012, 30.472819010000357)}

# %%
ds.name,
# ds.count,
# ds.shape,
# ds.height,
# ds.width,
# ds.crs,
# ds.transform,
# ds.discription

# %%
data.size
# Out:
# 4354020

# %%
data.dtype
# Out:
# dtype('uint8')

# %%
data.min()
# Out:
# 10

# %%
data.max()
# Out:
# 255

# %%
from rasterio.plot import show
show(ds)

# %%
from rasterio.plot import show, show_hist
show(ds, cmap="Spectral")

# %%
from rasterio.plot import show, show_hist
show(ds, cmap="winter")

# %%
from rasterio.plot import show, show_hist
show(ds, cmap="winter", title='Land Cover Map Of Napal')

# %%
from rasterio.plot import show, show_hist
show_hist(ds, bins=50, title='Land Cover Map Of Napal')

# %%
from itertools import count
with rasterio.open(r'/content/output/nepal_lc2020_out.tif', 'w',
                   driver = ds.driver,
                   height = ds.height,
                   width = ds.width,
                   count = ds.count,
                   crs = ds.crs,
                   transform = ds.transform,
                   dtype = data.dtype
                    ) as dst:
                     dst.write(data)

# %%
ds = rasterio.open(in_img)
data = ds.read()

# %%
data +10
# Out:
# array([[[9, 9, 9, ..., 9, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9],
#         ...,
#         [9, 9, 9, ..., 9, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9],
#         [9, 9, 9, ..., 9, 9, 9]]], dtype=uint8)

# %%
data -3
# Out:
# array([[[252, 252, 252, ..., 252, 252, 252],
#         [252, 252, 252, ..., 252, 252, 252],
#         [252, 252, 252, ..., 252, 252, 252],
#         ...,
#         [252, 252, 252, ..., 252, 252, 252],
#         [252, 252, 252, ..., 252, 252, 252],
#         [252, 252, 252, ..., 252, 252, 252]]], dtype=uint8)

# %%
data = data-10
data
# Out:
# array([[[235, 235, 235, ..., 235, 235, 235],
#         [235, 235, 235, ..., 235, 235, 235],
#         [235, 235, 235, ..., 235, 235, 235],
#         ...,
#         [235, 235, 235, ..., 235, 235, 235],
#         [235, 235, 235, ..., 235, 235, 235],
#         [235, 235, 235, ..., 235, 235, 235]]], dtype=uint8)

# %%
data = data/5
data
# Out:
# array([[[47., 47., 47., ..., 47., 47., 47.],
#         [47., 47., 47., ..., 47., 47., 47.],
#         [47., 47., 47., ..., 47., 47., 47.],
#         ...,
#         [47., 47., 47., ..., 47., 47., 47.],
#         [47., 47., 47., ..., 47., 47., 47.],
#         [47., 47., 47., ..., 47., 47., 47.]]])

# %%
data.min()
# Out:
# 0.0

# %%
data.max()
# Out:
# 49.6

# %%
in_img1 = r'/content/data/srtm_57_08_1.tif'
ds1 = rasterio.open(in_img)
ds1
# Out:
# <open DatasetReader name='/content/data/nepal_lc_2020.tif' mode='r'>

# %%
from rasterio.plot import show, show_hist
show(ds1, cmap="Spectral")

# %%
ds1.crs
# Out:
# CRS.from_epsg(4326)

# %%
ds1.count
# Out:
# 1

# %%
ds1.height
# Out:
# 1485

# %%
ds1.width
# Out:
# 2932

# %%
ds1.max

# %%
ds1 = rasterio.open(in_img1)
data1 = ds1.read()
